# %% [markdown]
# ## Analysis for Selected Housing characteristics with year structure built, rental vacancy rates, rent, and gross rent as percentage of income (filter by all tracts within Los Angeles County): https://data.census.gov/table/ACSSDP1YCD1192023.DP04?q=DP04:%20Selected%20Housing%20Characteristics

# %%
import pandas as pd

# %%
# load a data file
# note the relative filepath! where is this file located?
df = pd.read_csv('data/Rent_Data.csv',
dtype=
    {
        'FIPS':str
    }
)

# %%
df.shape
# Out:
# (2498, 574)

# %%
df.head()
# Out:
#      GEO_ID        FIPS  DP04_0001E  DP04_0001M  DP04_0002E  DP04_0002M  \
# 0  1400000U  6037101110        1679          96        1558         126
# 1  1400000U  6037101122        1452         170        1407         166
# 2  1400000U  6037101220        1380         202        1357         201
# 3  1400000U  6037101221        1569         283        1483         285
# 4  1400000U  6037101222        1036         138         948         149
#
#    DP04_0003E  DP04_0003M DP04_0004E DP04_0004M  ... DP04_0139PE DP04_0139PM  \
# 0         121          94          0        4.9  ...        22.8        13.1
# 1          45          46          0        3.7  ...         3.2         6.3
# 2          23          23          0        6.9  ...         5.3         4.7
# 3          86          65          0       12.1  ...         6.3         6.4
# 4          88          66          0       39.2  ...        13.7        10.9
#
#    DP04_0140PE  DP04_0140PM  DP04_0141PE  DP04_0141PM  DP04_0142PE  \
# 0          2.8          2.9          8.3            6         49.7
# 1           10         13.2          5.2          9.2         81.6
# 2         25.9         16.4         13.1          7.1         33.7
# 3         12.7          8.6          6.2          5.7         63.3
# 4          7.1          7.5          1.3          2.2         54.1
#
#    DP04_0142PM  DP04_0143PE  DP04_0143PM
# 0         13.4          (X)          (X)
# 1         19.3          (X)          (X)
# 2         13.6          (X)          (X)
# 3         12.5          (X)          (X)
# 4         13.3          (X)          (X)
#
# [5 rows x 574 columns]

# %%
df['FIPS'] ='0' + df['FIPS']

# %%
pd.set_option('display.max_columns', None)

# %%
df.sample()
# Out:
#       GEO_ID         FIPS  DP04_0001E  DP04_0001M  DP04_0002E  DP04_0002M  \
# 96  1400000U  06037113212        1000          66         972          55
#
#     DP04_0003E  DP04_0003M DP04_0004E DP04_0004M DP04_0005E DP04_0005M  \
# 96          28          38          0        6.9          0         10
#
#     DP04_0006E  DP04_0006M  DP04_0007E  DP04_0007M  DP04_0008E  DP04_0008M  \
# 96        1000          66         656          93          47          33
#
#     DP04_0009E  DP04_0009M  DP04_0010E  DP04_0010M  DP04_0011E  DP04_0011M  \
# 96           0          14           0          14          19          21
#
#     DP04_0012E  DP04_0012M  DP04_0013E  DP04_0013M  DP04_0014E  DP04_0014M  \
# 96           8          14         257          87          13          21
#
#     DP04_0015E  DP04_0015M  DP04_0016E  DP04_0016M  DP04_0017E  DP04_0017M  \
# 96           0          14        1000          66           0          14
#
#     DP04_0018E  DP04_0018M  DP04_0019E  DP04_0019M  DP04_0020E  DP04_0020M  \
# 96           0          14           0          14          24          27
#
#     DP04_0021E  DP04_0021M  DP04_0022E  DP04_0022M  DP04_0023E  DP04_0023M  \
# 96         211          91         258          83         335          95
#
#     DP04_0024E  DP04_0024M  DP04_0025E  DP04_0025M  DP04_0026E  DP04_0026M  \
# 96         157          69           0          14          15          22
#
#     DP04_0027E  DP04_0027M  DP04_0028E  DP04_0028M  DP04_0029E  DP04_0029M  \
# 96        1000          66          49          51           0          14
#
#     DP04_0030E  DP04_0030M  DP04_0031E  DP04_0031M  DP04_0032E  DP04_0032M  \
# 96          49          38         239         105         126          66
#
#     DP04_0033E  DP04_0033M  DP04_0034E  DP04_0034M  DP04_0035E  DP04_0035M  \
# 96         259          81         115          60         122          60
#
#     DP04_0036E  DP04_0036M DP04_0037E DP04_0037M  DP04_0038E  DP04_0038M  \
# 96          41          31        5.6        0.4        1000          66
#
#     DP04_0039E  DP04_0039M  DP04_0040E  DP04_0040M  DP04_0041E  DP04_0041M  \
# 96          49          51          62          46         158          79
#
#     DP04_0042E  DP04_0042M  DP04_0043E  DP04_0043M  DP04_0044E  DP04_0044M  \
# 96         471         107         231          90          29          28
#
#     DP04_0045E  DP04_0045M  DP04_0046E  DP04_0046M  DP04_0047E  DP04_0047M  \
# 96         972          55         571         103         401         107
#
#    DP04_0048E DP04_0048M DP04_0049E DP04_0049M  DP04_0050E  DP04_0050M  \
# 96       2.39       0.35       3.46       0.84         972          55
#
#     DP04_0051E  DP04_0051M  DP04_0052E  DP04_0052M  DP04_0053E  DP04_0053M  \
# 96          89          72          96          63         330         110
#
#     DP04_0054E  DP04_0054M  DP04_0055E  DP04_0055M  DP04_0056E  DP04_0056M  \
# 96         155          63         105          50         197          74
#
#     DP04_0057E  DP04_0057M  DP04_0058E  DP04_0058M  DP04_0059E  DP04_0059M  \
# 96         972          55          25          29         311          89
#
#     DP04_0060E  DP04_0060M  DP04_0061E  DP04_0061M  DP04_0062E  DP04_0062M  \
# 96         322          99         314          71         972          55
#
#     DP04_0063E  DP04_0063M  DP04_0064E  DP04_0064M  DP04_0065E  DP04_0065M  \
# 96         709          93          37          42         205          85
#
#     DP04_0066E  DP04_0066M  DP04_0067E  DP04_0067M  DP04_0068E  DP04_0068M  \
# 96           0          14           0          14           0          14
#
#     DP04_0069E  DP04_0069M  DP04_0070E  DP04_0070M  DP04_0071E  DP04_0071M  \
# 96           0          14           0          14          21          33
#
#     DP04_0072E  DP04_0072M  DP04_0073E  DP04_0073M  DP04_0074E  DP04_0074M  \
# 96         972          55           0          14           0          14
#
#     DP04_0075E  DP04_0075M  DP04_0076E  DP04_0076M  DP04_0077E  DP04_0077M  \
# 96          21          25         972          55         889          80
#
#     DP04_0078E  DP04_0078M  DP04_0079E  DP04_0079M  DP04_0080E  DP04_0080M  \
# 96          38          51          45          39         571         103
#
#     DP04_0081E  DP04_0081M  DP04_0082E  DP04_0082M  DP04_0083E  DP04_0083M  \
# 96          29          28          14          20           0          14
#
#     DP04_0084E  DP04_0084M  DP04_0085E  DP04_0085M  DP04_0086E  DP04_0086M  \
# 96           0          14           9          15           7          12
#
#     DP04_0087E  DP04_0087M  DP04_0088E  DP04_0088M DP04_0089E DP04_0089M  \
# 96         445          96          67          48     769500      69389
#
#     DP04_0090E  DP04_0090M  DP04_0091E  DP04_0091M  DP04_0092E  DP04_0092M  \
# 96         571         103         368          90         203          72
#
#     DP04_0093E  DP04_0093M  DP04_0094E  DP04_0094M  DP04_0095E  DP04_0095M  \
# 96         368          90           0          14          14          20
#
#     DP04_0096E  DP04_0096M  DP04_0097E  DP04_0097M  DP04_0098E  DP04_0098M  \
# 96          12          20           0          14          75          50
#
#     DP04_0099E  DP04_0099M  DP04_0100E  DP04_0100M DP04_0101E DP04_0101M  \
# 96          59          47         208          85       3231        538
#
#     DP04_0102E  DP04_0102M  DP04_0103E  DP04_0103M  DP04_0104E  DP04_0104M  \
# 96         203          72          10          16           0          14
#
#     DP04_0105E  DP04_0105M  DP04_0106E  DP04_0106M  DP04_0107E  DP04_0107M  \
# 96          46          49          33          30          27          28
#
#     DP04_0108E  DP04_0108M DP04_0109E DP04_0109M  DP04_0110E  DP04_0110M  \
# 96          87          44        846        212         368          90
#
#     DP04_0111E  DP04_0111M  DP04_0112E  DP04_0112M  DP04_0113E  DP04_0113M  \
# 96          67          52         110          52          28          25
#
#     DP04_0114E  DP04_0114M  DP04_0115E  DP04_0115M  DP04_0116E  DP04_0116M  \
# 96           0          14         163          75           0          14
#
#     DP04_0117E  DP04_0117M  DP04_0118E  DP04_0118M  DP04_0119E  DP04_0119M  \
# 96         203          72          41          32          28          29
#
#     DP04_0120E  DP04_0120M  DP04_0121E  DP04_0121M  DP04_0122E  DP04_0122M  \
# 96          50          36          30          45          13          19
#
#     DP04_0123E  DP04_0123M  DP04_0124E  DP04_0124M  DP04_0125E  DP04_0125M  \
# 96           0          14          41          30           0          14
#
#     DP04_0126E  DP04_0126M  DP04_0127E  DP04_0127M  DP04_0128E  DP04_0128M  \
# 96         369         103           0          14           0          14
#
#     DP04_0129E  DP04_0129M  DP04_0130E  DP04_0130M  DP04_0131E  DP04_0131M  \
# 96          11          17          75          69         141          91
#
#     DP04_0132E  DP04_0132M  DP04_0133E  DP04_0133M DP04_0134E DP04_0134M  \
# 96          95          57          47          34       2349        205
#
#     DP04_0135E  DP04_0135M  DP04_0136E  DP04_0136M  DP04_0137E  DP04_0137M  \
# 96          32          23         369         103          28          37
#
#     DP04_0138E  DP04_0138M  DP04_0139E  DP04_0139M  DP04_0140E  DP04_0140M  \
# 96           0          14          37          36          31          36
#
#     DP04_0141E  DP04_0141M  DP04_0142E  DP04_0142M  DP04_0143E  DP04_0143M  \
# 96           5           8         268         102          32          23
#
#     DP04_0001PE DP04_0001PM DP04_0002PE DP04_0002PM DP04_0003PE DP04_0003PM  \
# 96         1000         (X)        97.2         3.7         2.8         3.7
#
#    DP04_0004PE DP04_0004PM DP04_0005PE DP04_0005PM  DP04_0006PE DP04_0006PM  \
# 96         (X)         (X)         (X)         (X)         1000         (X)
#
#    DP04_0007PE DP04_0007PM DP04_0008PE DP04_0008PM DP04_0009PE DP04_0009PM  \
# 96        65.6         8.2         4.7         3.3           0         4.2
#
#    DP04_0010PE DP04_0010PM DP04_0011PE DP04_0011PM DP04_0012PE DP04_0012PM  \
# 96           0         4.2         1.9         2.1         0.8         1.4
#
#    DP04_0013PE DP04_0013PM DP04_0014PE DP04_0014PM DP04_0015PE DP04_0015PM  \
# 96        25.7         8.6         1.3         2.1           0         4.2
#
#     DP04_0016PE DP04_0016PM DP04_0017PE DP04_0017PM DP04_0018PE DP04_0018PM  \
# 96         1000         (X)           0         4.2           0         4.2
#
#    DP04_0019PE DP04_0019PM DP04_0020PE DP04_0020PM DP04_0021PE DP04_0021PM  \
# 96           0         4.2         2.4         2.7        21.1         8.9
#
#    DP04_0022PE DP04_0022PM DP04_0023PE DP04_0023PM DP04_0024PE DP04_0024PM  \
# 96        25.8         7.6        33.5         9.7        15.7         6.8
#
#    DP04_0025PE DP04_0025PM DP04_0026PE DP04_0026PM  DP04_0027PE DP04_0027PM  \
# 96           0         4.2         1.5         2.2         1000         (X)
#
#    DP04_0028PE DP04_0028PM DP04_0029PE DP04_0029PM DP04_0030PE DP04_0030PM  \
# 96         4.9         5.2           0         4.2         4.9         3.7
#
#    DP04_0031PE DP04_0031PM DP04_0032PE DP04_0032PM DP04_0033PE DP04_0033PM  \
# 96        23.9        10.1        12.6         6.2        25.9         8.2
#
#    DP04_0034PE DP04_0034PM DP04_0035PE DP04_0035PM DP04_0036PE DP04_0036PM  \
# 96        11.5         6.1        12.2           6         4.1         3.1
#
#    DP04_0037PE DP04_0037PM  DP04_0038PE DP04_0038PM DP04_0039PE DP04_0039PM  \
# 96         (X)         (X)         1000         (X)         4.9         5.2
#
#    DP04_0040PE DP04_0040PM DP04_0041PE DP04_0041PM DP04_0042PE DP04_0042PM  \
# 96         6.2         4.5        15.8         7.9        47.1         9.4
#
#    DP04_0043PE DP04_0043PM DP04_0044PE DP04_0044PM  DP04_0045PE DP04_0045PM  \
# 96        23.1         9.4         2.9         2.8          972         (X)
#
#    DP04_0046PE DP04_0046PM DP04_0047PE DP04_0047PM DP04_0048PE DP04_0048PM  \
# 96        58.7        10.6        41.3        10.6         (X)         (X)
#
#    DP04_0049PE DP04_0049PM  DP04_0050PE DP04_0050PM DP04_0051PE DP04_0051PM  \
# 96         (X)         (X)          972         (X)         9.2         7.3
#
#    DP04_0052PE DP04_0052PM DP04_0053PE DP04_0053PM DP04_0054PE DP04_0054PM  \
# 96         9.9         6.6          34        10.5        15.9         6.9
#
#    DP04_0055PE DP04_0055PM DP04_0056PE DP04_0056PM  DP04_0057PE DP04_0057PM  \
# 96        10.8         5.2        20.3         7.5          972         (X)
#
#    DP04_0058PE DP04_0058PM DP04_0059PE DP04_0059PM DP04_0060PE DP04_0060PM  \
# 96         2.6           3          32         8.6        33.1         9.9
#
#    DP04_0061PE DP04_0061PM  DP04_0062PE DP04_0062PM DP04_0063PE DP04_0063PM  \
# 96        32.3         7.7          972         (X)        72.9         9.2
#
#    DP04_0064PE DP04_0064PM DP04_0065PE DP04_0065PM DP04_0066PE DP04_0066PM  \
# 96         3.8         4.3        21.1         8.4           0         4.3
#
#    DP04_0067PE DP04_0067PM DP04_0068PE DP04_0068PM DP04_0069PE DP04_0069PM  \
# 96           0         4.3           0         4.3           0         4.3
#
#    DP04_0070PE DP04_0070PM DP04_0071PE DP04_0071PM  DP04_0072PE DP04_0072PM  \
# 96           0         4.3         2.2         3.4          972         (X)
#
#    DP04_0073PE DP04_0073PM DP04_0074PE DP04_0074PM DP04_0075PE DP04_0075PM  \
# 96           0         4.3           0         4.3         2.2         2.5
#
#     DP04_0076PE DP04_0076PM DP04_0077PE DP04_0077PM DP04_0078PE DP04_0078PM  \
# 96          972         (X)        91.5         6.1         3.9         5.2
#
#    DP04_0079PE DP04_0079PM  DP04_0080PE DP04_0080PM DP04_0081PE DP04_0081PM  \
# 96         4.6           4          571         (X)         5.1         4.9
#
#    DP04_0082PE DP04_0082PM DP04_0083PE DP04_0083PM DP04_0084PE DP04_0084PM  \
# 96         2.5         3.6           0         7.2           0         7.2
#
#    DP04_0085PE DP04_0085PM DP04_0086PE DP04_0086PM DP04_0087PE DP04_0087PM  \
# 96         1.6         2.6         1.2         2.1        77.9         9.5
#
#    DP04_0088PE DP04_0088PM DP04_0089PE DP04_0089PM  DP04_0090PE DP04_0090PM  \
# 96        11.7         8.2         (X)         (X)          571         (X)
#
#    DP04_0091PE DP04_0091PM DP04_0092PE DP04_0092PM  DP04_0093PE DP04_0093PM  \
# 96        64.4        10.9        35.6        10.9          368         (X)
#
#    DP04_0094PE DP04_0094PM DP04_0095PE DP04_0095PM DP04_0096PE DP04_0096PM  \
# 96           0        10.9         3.8         5.5         3.3         5.3
#
#    DP04_0097PE DP04_0097PM DP04_0098PE DP04_0098PM DP04_0099PE DP04_0099PM  \
# 96           0        10.9        20.4        13.4          16        12.2
#
#    DP04_0100PE DP04_0100PM DP04_0101PE DP04_0101PM  DP04_0102PE DP04_0102PM  \
# 96        56.5        16.1         (X)         (X)          203         (X)
#
#    DP04_0103PE DP04_0103PM DP04_0104PE DP04_0104PM DP04_0105PE DP04_0105PM  \
# 96         4.9           8           0        18.8        22.7          22
#
#    DP04_0106PE DP04_0106PM DP04_0107PE DP04_0107PM DP04_0108PE DP04_0108PM  \
# 96        16.3        14.5        13.3        13.8        42.9        19.6
#
#    DP04_0109PE DP04_0109PM  DP04_0110PE DP04_0110PM DP04_0111PE DP04_0111PM  \
# 96         (X)         (X)          368         (X)        18.2        12.6
#
#    DP04_0112PE DP04_0112PM DP04_0113PE DP04_0113PM DP04_0114PE DP04_0114PM  \
# 96        29.9          14         7.6         6.5           0        10.9
#
#    DP04_0115PE DP04_0115PM DP04_0116PE DP04_0116PM  DP04_0117PE DP04_0117PM  \
# 96        44.3        16.4         (X)         (X)          203         (X)
#
#    DP04_0118PE DP04_0118PM DP04_0119PE DP04_0119PM DP04_0120PE DP04_0120PM  \
# 96        20.2        15.6        13.8        14.3        24.6        16.5
#
#    DP04_0121PE DP04_0121PM DP04_0122PE DP04_0122PM DP04_0123PE DP04_0123PM  \
# 96        14.8        20.5         6.4         9.5           0        18.8
#
#    DP04_0124PE DP04_0124PM DP04_0125PE DP04_0125PM  DP04_0126PE DP04_0126PM  \
# 96        20.2        14.5         (X)         (X)          369         (X)
#
#    DP04_0127PE DP04_0127PM DP04_0128PE DP04_0128PM DP04_0129PE DP04_0129PM  \
# 96           0        10.9           0        10.9           3         4.7
#
#    DP04_0130PE DP04_0130PM DP04_0131PE DP04_0131PM DP04_0132PE DP04_0132PM  \
# 96        20.3        18.1        38.2          20        25.7        15.6
#
#    DP04_0133PE DP04_0133PM DP04_0134PE DP04_0134PM DP04_0135PE DP04_0135PM  \
# 96        12.7         9.1         (X)         (X)         (X)         (X)
#
#     DP04_0136PE DP04_0136PM DP04_0137PE DP04_0137PM DP04_0138PE DP04_0138PM  \
# 96          369         (X)         7.6         9.9           0        10.9
#
#    DP04_0139PE DP04_0139PM DP04_0140PE DP04_0140PM DP04_0141PE DP04_0141PM  \
# 96          10        10.4         8.4         9.9         1.4         2.2
#
#    DP04_0142PE DP04_0142PM DP04_0143PE DP04_0143PM
# 96        72.6          16         (X)         (X)

# %%
df.FIPS.head()
# Out:
# 0    06037101110
# 1    06037101122
# 2    06037101220
# 3    06037101221
# 4    06037101222
# Name: FIPS, dtype: object

# %% [markdown]
# ### Defining columns to keep (amount of different value of owner-occupied units)
#
# According to the data dictionary, our dataframe includes many, many columns. While they may be useful for future analysis, let's only keep the columns that we will be using for this session, mainly a selected characteristic of vVALUE, Estimate owner-occupied units
# - FIPS:         Identifier
# - DP04_0080E:	Estimate VALUE of Owner-occupied units
# - DP04_0081E:	Estimate VALUE of Owner-occupied units Less than $50,000
# - DP04_0082E:	Estimate VALUE of Owner-occupied units $50,000 to $99,999
# - DP04_0083E:	Estimate VALUE of Owner-occupied units $100,000 to $149,999
# - DP04_0084E:	Estimate VALUE of Owner-occupied units $150,000 to $199,999
# - DP04_0085E:	Estimate VALUE of Owner-occupied units $200,000 to $299,999
# - DP04_0086E:	Estimate VALUE of Owner-occupied units $300,000 to $499,999
# - DP04_0087E:	Estimate VALUE of Owner-occupied units $500,000 to $999,999
# - DP04_0088E:	Estimate VALUE of Owner-occupied units $1,000,000 or more
# - DP04_0089E:	Estimate VALUE of Owner-occupied units Median (dollars)

# %%
# define columns to keep; you will have to look at your source's metadata to determine which columns to keep and what they mean
columns_to_keep = ['FIPS',
                   'DP04_0080E',
                   'DP04_0081E',
                   'DP04_0082E',
                   'DP04_0083E',
                   'DP04_0084E',
                   'DP04_0085E',
                   'DP04_0086E',
                   'DP04_0087E',
                   'DP04_0088E',
                   'DP04_0089E']
# add it to a new dataframe
df2 = df[columns_to_keep]

# %%
# returns list of columns 
columns = list(df2) # this is the same as df.columns.to_list()
columns
# Out:
# ['FIPS',
#  'DP04_0080E',
#  'DP04_0081E',
#  'DP04_0082E',
#  'DP04_0083E',
#  'DP04_0084E',
#  'DP04_0085E',
#  'DP04_0086E',
#  'DP04_0087E',
#  'DP04_0088E',
#  'DP04_0089E']

# %%
df2.columns = ['FIPS',
'Owner-occupied units',
'Less than $50,000',
'$50,000 to $99,999',
'$100,000 to $149,999',
'$150,000 to $199,999',
'$200,000 to $299,999',
'$300,000 to $499,999',
'$500,000 to $999,999',
'$1,000,000 or more',
'Median (dollars)']

# %%
df2.sample(5)
# Out:
#              FIPS  Owner-occupied units  Less than $50,000  \
# 104   06037113239                   211                110
# 876   06037239701                   394                  8
# 2068  06037600501                   566                  0
# 159   06037120103                    52                  0
# 1458  06037460302                  1206                  7
#
#       $50,000 to $99,999  $100,000 to $149,999  $150,000 to $199,999  \
# 104                    3                    18                    15
# 876                   17                     0                     0
# 2068                  24                     0                     0
# 159                    0                     0                     0
# 1458                   9                     0                     0
#
#       $200,000 to $299,999  $300,000 to $499,999  $500,000 to $999,999  \
# 104                     28                    10                    27
# 876                     41                   101                   185
# 2068                     0                    21                   462
# 159                     16                    13                    23
# 1458                     0                    29                   889
#
#       $1,000,000 or more Median (dollars)
# 104                    0                -
# 876                   42           540500
# 2068                  59           818200
# 159                    0           376900
# 1458                 272           824300

# %%
df2['Owner-occupied units'].head()
# Out:
# 0     798
# 1    1096
# 2     596
# 3     329
# 4      75
# Name: Owner-occupied units, dtype: int64

# %%
df2['Owner-occupied units'].describe()
# Out:
# count    2498.000000
# mean      625.383106
# std       441.485515
# min         0.000000
# 25%       287.000000
# 50%       538.500000
# 75%       898.500000
# max      2520.000000
# Name: Owner-occupied units, dtype: float64

# %%
# plot it as a historgram with 50 bins
df2['Owner-occupied units'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.scatter(x='$50,000 to $99,999',y='$1,000,000 or more')
# Out:
# <Axes: xlabel='$50,000 to $99,999', ylabel='$1,000,000 or more'>

# %%
df_sorted = df2.sort_values(by='Owner-occupied units',ascending = False)

# %%
# display the data, but just a few columns to keep it clean
df_sorted[['FIPS','Owner-occupied units']].head(10)
# Out:
#              FIPS  Owner-occupied units
# 69    06037108202                  2520
# 2438  06037920121                  2483
# 2409  06037920031                  2343
# 2406  06037920028                  2189
# 2400  06037920013                  2169
# 1995  06037573601                  2159
# 1455  06037460101                  2149
# 2290  06037800324                  2123
# 2417  06037920043                  2110
# 1485  06037462500                  2102

# %%
# plot it
df_sorted.head(10).plot.bar(x='FIPS',
                            y='Owner-occupied units')
# Out:
# <Axes: xlabel='FIPS'>

# %%
# Make it prettier with a title
df_sorted.head(10).plot.barh(x='FIPS',
                            y='Owner-occupied units', 
                            title='Top 10 Census Tracts with Most Owner-occupied units in Los Angeles County in 2025',
                            color='#9AB5C0')
# Out:
# <Axes: title={'center': 'Top 10 Census Tracts with Most Owner-occupied units in Los Angeles County in 2025'}, ylabel='FIPS'>

# %% [markdown]
# ####MAPPING

# %%
import geopandas as gpd

# %%
# read in a geojson file downloaded from the LA Times
caTracts=gpd.read_file('data/2020_Census_Tracts.geojson')
caTracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0      4992  101110  1011.10  1.229562e+07   15083.854287
# 1      4993  101122  1011.22  2.845774e+07   31671.455844
# 2      4994  101220  1012.20  7.522093e+06   12698.783810
# 3      4995  101221  1012.21  3.812000e+06    9161.710543
# 4      4996  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.29793 34.26323, -118.30082 34.2...
# 1  POLYGON ((-118.27743 34.25991, -118.27743 34.2...
# 2  POLYGON ((-118.27818 34.25577, -118.27887 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.2559, -118.28697 34.25...

# %%
# plot it!
caTracts.plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
# tell me more about this dataset
caTracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2496 entries, 0 to 2495
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       2496 non-null   int32
#  1   CT20           2496 non-null   object
#  2   LABEL          2496 non-null   object
#  3   ShapeSTArea    2496 non-null   float64
#  4   ShapeSTLength  2496 non-null   float64
#  5   geometry       2496 non-null   geometry
# dtypes: float64(2), geometry(1), int32(1), object(2)
# memory usage: 107.4+ KB

# %%
# we only really need FIPS and geometry, so let's subset the data
caTracts = caTracts[['CT20','geometry']]
caTracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.29793 34.26323, -118.30082 34.2...
# 1  101122  POLYGON ((-118.27743 34.25991, -118.27743 34.2...
# 2  101220  POLYGON ((-118.27818 34.25577, -118.27887 34.2...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.2559, -118.28697 34.25...

# %%
# create a FIPS column
caTracts['FIPS'] ='06' + '037' + caTracts['CT20']
# Out:
# /opt/conda/lib/python3.11/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
la_tracts = caTracts

# %%
# check it!
la_tracts.head()
# Out:
#      CT20                                           geometry         FIPS
# 0  101110  POLYGON ((-118.29793 34.26323, -118.30082 34.2...  06037101110
# 1  101122  POLYGON ((-118.27743 34.25991, -118.27743 34.2...  06037101122
# 2  101220  POLYGON ((-118.27818 34.25577, -118.27887 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.2559, -118.28697 34.25...  06037101222

# %%
print(la_tracts['FIPS'].dtype)
print(df2['FIPS'].dtype)
# Out:
# object
# object

# %%
# create a new dataframe based on the join
la_tracts_rent=la_tracts.merge(df2,on="FIPS")

# %%
df2.sample(5)
# Out:
#              FIPS  Owner-occupied units  Less than $50,000  \
# 1513  06037480303                   276                  0
# 1611  06037502700                  1379                 57
# 1719  06037534002                   230                 65
# 1387  06037430302                  1347                 53
# 538   06037199700                   238                  0
#
#       $50,000 to $99,999  $100,000 to $149,999  $150,000 to $199,999  \
# 1513                   0                     0                     0
# 1611                  29                     0                     0
# 1719                   0                     6                     0
# 1387                   0                    15                     0
# 538                    0                     0                     9
#
#       $200,000 to $299,999  $300,000 to $499,999  $500,000 to $999,999  \
# 1513                     8                    13                   234
# 1611                     0                   294                   982
# 1719                     3                    47                   109
# 1387                     0                     0                   638
# 538                     10                     0                   219
#
#       $1,000,000 or more Median (dollars)
# 1513                  21           647000
# 1611                  17           582800
# 1719                   0           487200
# 1387                 641           984100
# 538                    0           670100

# %%
common_fips = set(la_tracts['FIPS']).intersection(set(df2['FIPS']))
print(len(common_fips))  # Number of matching FIPS
# Out:
# 2496

# %%
# what does it look like now?
la_tracts_rent.sample(10)
# Out:
#         CT20                                           geometry         FIPS  \
# 1823  543905  POLYGON ((-118.24228 33.82422, -118.24235 33.8...  06037543905
# 1953  571300  POLYGON ((-118.14244 33.84712, -118.14248 33.8...  06037571300
# 1557  482801  POLYGON ((-118.10653 34.04041, -118.10699 34.0...  06037482801
# 652   211703  POLYGON ((-118.30913 34.06897, -118.31037 34.0...  06037211703
# 1803  543306  POLYGON ((-118.223 33.8392, -118.22314 33.8392...  06037543306
# 292   133000  POLYGON ((-118.55353 34.20098, -118.55568 34.2...  06037133000
# 1073  296300  POLYGON ((-118.29106 33.75378, -118.29125 33.7...  06037296300
# 892   240902  POLYGON ((-118.25482 33.93525, -118.25491 33.9...  06037240902
# 988   271500  POLYGON ((-118.43023 34.0159, -118.4307 34.016...  06037271500
# 1505  480602  POLYGON ((-118.15028 34.12404, -118.15045 34.1...  06037480602
#
#       Owner-occupied units  Less than $50,000  $50,000 to $99,999  \
# 1823                   466                  0                   0
# 1953                  1365                  0                  45
# 1557                   882                  6                   9
# 652                    164                  0                   0
# 1803                  1447                 55                  31
# 292                   1025                  0                   9
# 1073                  1308                 44                   0
# 892                    286                  0                   0
# 988                    755                  0                   0
# 1505                   540                  0                   0
#
#       $100,000 to $149,999  $150,000 to $199,999  $200,000 to $299,999  \
# 1823                     0                    10                    77
# 1953                    17                     0                    10
# 1557                     0                     0                    12
# 652                      0                     0                     0
# 1803                    82                    52                    94
# 292                      0                     0                    12
# 1073                     0                    11                    34
# 892                      0                     0                    19
# 988                      9                     7                     0
# 1505                     6                     0                     0
#
#       $300,000 to $499,999  $500,000 to $999,999  $1,000,000 or more  \
# 1823                   180                   199                   0
# 1953                    10                   935                 348
# 1557                    27                   813                  15
# 652                     57                    88                  19
# 1803                   142                   934                  57
# 292                    198                   741                  65
# 1073                   177                   850                 192
# 892                    153                   114                   0
# 988                      0                    48                 691
# 1505                    14                   112                 408
#
#      Median (dollars)
# 1823           471200
# 1953           856100
# 1557           784400
# 652            602500
# 1803           641700
# 292            630100
# 1073           653200
# 892            475400
# 988        2,000,000+
# 1505          1592600

# %%
la_tracts_rent.plot(figsize=(12,10),
                 column='Owner-occupied units',
                 legend=True, 
                 scheme='natural_breaks')
# Out:
# <Axes: >

# %%
la_tracts_rent.plot(figsize=(12,10),
                 column='Owner-occupied units',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <Axes: >

# %%
la_tracts_rent.plot(figsize=(12,10),
                 column='Owner-occupied units',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <Axes: >

# %%
la_tracts_rent['PCT_expensive'] = la_tracts_rent['$1,000,000 or more']/la_tracts_rent['Owner-occupied units']*100
la_tracts_rent['PCT_low'] = la_tracts_rent['Less than $50,000']/la_tracts_rent['Owner-occupied units']*100
la_tracts_rent['PCT_most'] = la_tracts_rent['$500,000 to $999,999']/la_tracts_rent['Owner-occupied units']*100

# %%
la_tracts_rent[la_tracts_rent.PCT_low > 10].plot(figsize=(6,5))
# Out:
# <Axes: >

# %%
la_tracts_rent[la_tracts_rent.PCT_expensive > 90].plot(figsize=(6,5))
# Out:
# <Axes: >

# %%
la_tracts_rent[la_tracts_rent.PCT_most > 80].plot(figsize=(6,5))
# Out:
# <Axes: >

# %% [markdown]
# ### Defining columns to keep (Rent)
#
# According to the data dictionary, our dataframe includes many, many columns. While they may be useful for future analysis, let's only keep the columns that we will be using for this session, mainly Estimate owner-occupied units value
# - FIPS:         Identifier
# - DP04_0126E：	Estimate GROSS RENT Occupied units paying rent
# - DP04_0127E：	Estimate GROSS RENT Occupied units paying rent Less than $500
# - DP04_0128E：	Estimate GROSS RENT Occupied units paying rent $500 to $999
# - DP04_0129E：	Estimate GROSS RENT Occupied units paying rent $1,000 to $1,499
# - DP04_0130E：	Estimate GROSS RENT Occupied units paying rent $1,500 to $1,999
# - DP04_0131E：	Estimate GROSS RENT Occupied units paying rent $2,000 to $2,499
# - DP04_0132E：	Estimate GROSS RENT Occupied units paying rent $2,500 to $2,999
# - DP04_0133E：	Estimate GROSS RENT Occupied units paying rent $3,000 or more
# - DP04_0134E：	Estimate GROSS RENT Occupied units paying rent Median (dollars)
# - DP04_0135E：	Estimate GROSS RENT Occupied units paying rent No rent paid

# %%
# define columns to keep; you will have to look at your source's metadata to determine which columns to keep and what they mean
columns_to_keep = ['FIPS',
                   'DP04_0126E',
                   'DP04_0127E',
                   'DP04_0128E',
                   'DP04_0129E',
                   'DP04_0130E',
                   'DP04_0131E',
                   'DP04_0132E',
                   'DP04_0133E',
                   'DP04_0134E',
                   'DP04_0135E']
# add it to a new dataframe
df3 = df[columns_to_keep]

# %%
columns = list(df3) 
columns
# Out:
# ['FIPS',
#  'DP04_0126E',
#  'DP04_0127E',
#  'DP04_0128E',
#  'DP04_0129E',
#  'DP04_0130E',
#  'DP04_0131E',
#  'DP04_0132E',
#  'DP04_0133E',
#  'DP04_0134E',
#  'DP04_0135E']

# %%
df3.columns = ['FIPS',
'GROSS RENT Occupied units',
'Rent pay less than $500',
'Rent pay between $500 to $999',
'Rent pay between $1000 to $1,499',
'Rent pay between $1,500 to $1,999',
'Rent pay between $2,000 to $2,499',
'Rent pay between $2,500 to $2,999',
'Rent pay between $3,000 or more',
'Estimate GROSS RENT Occupied units paying rent Median (dollars)',
'Estimate GROSS RENT Occupied units paying rent No rent paid']

# %%
df3.sample(5)
# Out:
#              FIPS  GROSS RENT Occupied units  Rent pay less than $500  \
# 2079  06037601001                        882                      185
# 2007  06037574800                        604                        0
# 1178  06037400206                        137                        0
# 811   06037231901                        522                       17
# 488   06037191820                       1792                        0
#
#       Rent pay between $500 to $999  Rent pay between $1000 to $1,499  \
# 2079                             30                               190
# 2007                              0                               165
# 1178                              9                                 0
# 811                              38                               193
# 488                              79                               278
#
#       Rent pay between $1,500 to $1,999  Rent pay between $2,000 to $2,499  \
# 2079                                245                                211
# 2007                                304                                122
# 1178                                 21                                  0
# 811                                 124                                 67
# 488                                 422                                302
#
#       Rent pay between $2,500 to $2,999  Rent pay between $3,000 or more  \
# 2079                                  0                               21
# 2007                                  0                               13
# 1178                                 10                               97
# 811                                   0                               83
# 488                                 103                              608
#
#      Estimate GROSS RENT Occupied units paying rent Median (dollars)  \
# 2079                                               1573
# 2007                                               1725
# 1178                                             3,500+
# 811                                                1552
# 488                                                2194
#
#       Estimate GROSS RENT Occupied units paying rent No rent paid
# 2079                                                 23
# 2007                                                 48
# 1178                                                 50
# 811                                                   0
# 488                                                  13

# %%
df3['GROSS RENT Occupied units'].describe()
# Out:
# count    2498.000000
# mean      711.832666
# std       508.698635
# min         0.000000
# 25%       330.500000
# 50%       633.500000
# 75%       985.000000
# max      4738.000000
# Name: GROSS RENT Occupied units, dtype: float64

# %%
df3['GROSS RENT Occupied units'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3.plot.scatter(x='Rent pay between $500 to $999',y='Rent pay between $3,000 or more')
# Out:
# <Axes: xlabel='Rent pay between $500 to $999', ylabel='Rent pay between $3,000 or more'>

# %%
Rdf_sorted = df3.sort_values(by='GROSS RENT Occupied units',ascending = False)

# %%
# display the data, but just a few columns to keep it clean
Rdf_sorted[['FIPS','GROSS RENT Occupied units']].head(10)
# Out:
#              FIPS  GROSS RENT Occupied units
# 2278  06037702900                       4738
# 606   06037207902                       3908
# 2239  06037700200                       3704
# 2255  06037701402                       3387
# 2264  06037701902                       3360
# 1028  06037275604                       3273
# 472   06037191000                       3179
# 2237  06037700101                       3156
# 2025  06037576001                       2877
# 2266  06037702102                       2807

# %%
# plot it
Rdf_sorted.head(10).plot.bar(x='FIPS',
                            y='GROSS RENT Occupied units')
# Out:
# <Axes: xlabel='FIPS'>

# %%
# Make it prettier with a title
Rdf_sorted.head(10).plot.barh(x='FIPS',
                            y='GROSS RENT Occupied units', 
                            title='Top 10 Census Tracts with Most Rent-Occupied units in Los Angeles County in 2023',
                            color='#D3E3D7')
# Out:
# <Axes: title={'center': 'Top 10 Census Tracts with Most Rent-Occupied units in Los Angeles County in 2023'}, ylabel='FIPS'>

# %%
la_tracts_gross=la_tracts.merge(df3,on="FIPS")

# %%
la_tracts_gross.plot(figsize=(12,10),
                 column='GROSS RENT Occupied units',
                 legend=True, 
                 scheme='natural_breaks')
# Out:
# <Axes: >

# %%
category_totals = df3[['Rent pay less than $500',
                       'Rent pay between $500 to $999',
                       'Rent pay between $1000 to $1,499',
                       'Rent pay between $1,500 to $1,999',
                       'Rent pay between $2,000 to $2,499',
                       'Rent pay between $2,500 to $2,999',
                       'Rent pay between $3,000 or more']].sum()

# %%
max_category = category_totals.idxmax()
max_value = category_totals.max()

# %%
print(f"The rent category with the highest total is '{max_category}' with a total of {max_value}.")
# Out:
# The rent category with the highest total is 'Rent pay between $1,500 to $1,999' with a total of 464299.

# %%
print(category_totals)
# Out:
# Rent pay less than $500               66326
# Rent pay between $500 to $999        116881
# Rent pay between $1000 to $1,499     341339
# Rent pay between $1,500 to $1,999    464299
# Rent pay between $2,000 to $2,499    348519
# Rent pay between $2,500 to $2,999    188280
# Rent pay between $3,000 or more      252514
# dtype: int64

# %%
la_tracts_gross['R_high'] = la_tracts_gross['Rent pay between $3,000 or more']/la_tracts_gross['GROSS RENT Occupied units']*100
la_tracts_gross['R_low'] = la_tracts_gross['Rent pay less than $500']/la_tracts_gross['GROSS RENT Occupied units']*100
la_tracts_gross['R_most'] = la_tracts_gross['Rent pay between $1,500 to $1,999']/la_tracts_gross['GROSS RENT Occupied units']*100

# %%
la_tracts_gross[la_tracts_gross.R_low > 30].plot(figsize=(6,5))
# Out:
# <Axes: >

# %%
la_tracts_gross[la_tracts_gross.R_high > 50].plot(figsize=(6,5))
# Out:
# <Axes: >

# %%
la_tracts_gross[la_tracts_gross.R_most > 50].plot(figsize=(6,5))
# Out:
# <Axes: >
