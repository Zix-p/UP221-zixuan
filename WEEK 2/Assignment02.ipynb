# %% [markdown]
# First of all, Library Import.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Then, import data.

# %%
Streetree = gpd.read_file('data/culver-city.geojson')

# %% [markdown]
# See how my data generally looks like by selecting 5 samples randomly.

# %%
Streetree.sample(5)
# Out:
#        Address         Street SideType   Tree                species  \
# 1101   11130.0    BRADDOCK DR    Front    1.0            CHINESE ELM
# 12796      2.0  SENIOR CENTER      Lot  136.0              WATER GUM
# 16183  12756.0  WASHINGTON BL     Side    1.0  AUSTRALIAN FLAME TREE
# 15552   9696.0  WASHINGTON BL     Side    6.0               YEW PINE
# 15617  10716.0  WASHINGTON BL    Front    1.0       MEXICAN FAN PALM
#
#                      BotanicalN    DBH height        lat         lon  \
# 1101           Ulmus parvifolia  25-30  30-45  34.004348 -118.405651
# 12796     Tristaniopsis laurina  07-12  01-15  34.013629 -118.403648
# 16183  Brachychiton acerifolius  07-12  15-30  33.995982 -118.435814
# 15552   Afrocarpus macrophyllus  13-18  15-30  34.021756 -118.395038
# 15617      Washingtonia robusta  19-24  45-60  34.016449 -118.405732
#
#                           geometry
# 1101   POINT (-118.40565 34.00435)
# 12796  POINT (-118.40365 34.01363)
# ...

# %% [markdown]
# Check the information of my data.

# %%
Streetree.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 16986 entries, 0 to 16985
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     16986 non-null  float64
#  1   Street      16986 non-null  object
#  2   SideType    16986 non-null  object
#  3   Tree        16986 non-null  float64
#  4   species     16986 non-null  object
#  5   BotanicalN  16986 non-null  object
#  6   DBH         16986 non-null  object
#  7   height      16986 non-null  object
#  8   lat         16986 non-null  float64
#  9   lon         16986 non-null  float64
#  10  geometry    16986 non-null  geometry
# dtypes: float64(4), geometry(1), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# See the shape of the data, how many coloumns and how many rows.

# %%
Streetree.shape
# Out:
# (16986, 11)

# %% [markdown]
# Check the head and first few rows.

# %%
Streetree.head()
# Out:
#    Address    Street SideType  Tree            species  \
# 0   5830.0  ADAMS BL     Side   1.0        VACANT SITE
# 1   5830.0  ADAMS BL     Side   2.0        VACANT SITE
# 2   5832.0  ADAMS BL    Front   1.0  INDIAN LAUREL FIG
# 3   5832.0  ADAMS BL    Front   2.0  INDIAN LAUREL FIG
# 4   5835.0  ADAMS BL    Front   1.0  INDIAN LAUREL FIG
#
#                   BotanicalN    DBH height        lat         lon  \
# 0                Vacant site    ---    ---  34.032224 -118.370990
# 1                Vacant site    ---    ---  34.032166 -118.371020
# 2  Ficus microcarpa 'Nitida'  13-18  15-30  34.032362 -118.371186
# 3  Ficus microcarpa 'Nitida'  13-18  15-30  34.032358 -118.371350
# 4  Ficus microcarpa 'Nitida'  25-30  15-30  34.032538 -118.371493
#
#                       geometry
# 0  POINT (-118.37099 34.03222)
# 1  POINT (-118.37102 34.03217)
# 2  POINT (-118.37119 34.03236)
# 3  POINT (-118.37135 34.03236)
# 4  POINT (-118.37149 34.03254)

# %% [markdown]
# Let the library plot the data for me.

# %%
Streetree.plot()
# Out:
# <Axes: >

# %% [markdown]
# Get to know the counts of values in my dataset.

# %%
Streetree.value_counts()
# Out:
# Address  Street                       SideType  Tree  species             BotanicalN               DBH    height  lat        lon          geometry
# 15626.0  JEFFERSON BL                 Front     6.0   YEW PINE            Afrocarpus macrophyllus  07-12  01-15   34.000210  -118.395276  POINT (-118.39528 34.00021)    1
# 0.0      New Tree - 34.0117854015403  Front     1.0   NEW TREE SITE       New Tree Site            ---    ---     34.011785  -118.402189  POINT (-118.40219 34.01179)    1
#          New Tree - 34.0121189016264  Front     1.0   NEW TREE SITE       New Tree Site            ---    ---     34.012119  -118.402269  POINT (-118.40227 34.01212)    1
#          New Tree - 34.0174280486395  Front     1.0   NEW TREE SITE       New Tree Site            ---    ---     34.017428  -118.386648  POINT (-118.38665 34.01743)    1
# ...

# %% [markdown]
# Filter the dataset by only choose side trees under the sidetype.

# %%
Streetree.query("SideType == 'Side'")
# Out:
#        Address       Street SideType  Tree                  species  \
# 0       5830.0     ADAMS BL     Side   1.0              VACANT SITE
# 1       5830.0     ADAMS BL     Side   2.0              VACANT SITE
# 15      3800.0  ALBRIGHT AV     Side   1.0                FERN PINE
# 16      3800.0  ALBRIGHT AV     Side   2.0                FERN PINE
# 98      4108.0  ALBRIGHT AV     Side   1.0              VACANT SITE
# ...        ...          ...      ...   ...                      ...
# 16980  13362.0     ZANJA ST     Side   1.0              VACANT SITE
# 16982  13388.0     ZANJA ST     Side   1.0  CANARY ISLAND DATE PALM
# 16983  13388.0     ZANJA ST     Side   2.0          ITALIAN CYPRESS
# 16984  13388.0     ZANJA ST     Side   3.0              WEEPING FIG
# 16985  13388.0     ZANJA ST     Side   4.0          ITALIAN CYPRESS
#
#                    BotanicalN    DBH height        lat         lon  \
# 0                 Vacant site    ---    ---  34.032224 -118.370990
# ...
